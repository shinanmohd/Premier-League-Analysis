# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
premierleague=pd.read_csv(r'C:\Users\hp\Data Analyst\csv\PremierLeagueSeason2024.csv')

# %%
premierleague
# Out:
#                         team  goals_scored  goals_conceded  wins  draws  \
# 0            Manchester City           179              66    55     12
# 1                  Liverpool           154              83    44     19
# 2                    Arsenal           146              68    46     12
# 3          Manchester United           130             102    39     17
# 4                    Chelsea           135              99    37     19
# 5          Tottenham Hotspur           142             106    38     14
# 6                Aston Villa           131             107    36     15
# 7            West Ham United           122             121    33     18
# 8                    Everton            87              99    30     17
# 9           Newcastle United           131             124    30     15
# 10            Crystal Palace            98             124    25     18
# 11   Wolverhampton Wanderers            86             117    25     16
# ...

# %% [markdown]
# ## Description

# %% [markdown]
# * team: The name of the football team.
# * goals_scored: The total number of goals scored by the team during the season.
# * goals_conceded: The total number of goals conceded by the team during the season.
# * wins: The number of matches won by the team.
# * draws: The number of matches that ended in a draw.
# * losses: The number of matches lost by the team.
# * points: The total number of points accumulated by the team (based on wins and draws).
# * goal_difference: The difference between goals scored and goals conceded (goals scored minus goals conceded).
# * rank: The team's final rank in the league standings.

# %% [markdown]
# ## Objective
# * To predict the team that will win the premier league 2025

# %%
premierleague.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   team             24 non-null     object
#  1   goals_scored     24 non-null     int64
#  2   goals_conceded   24 non-null     int64
#  3   wins             24 non-null     int64
#  4   draws            24 non-null     int64
#  5   losses           24 non-null     int64
#  6   points           24 non-null     int64
#  7   goal_difference  24 non-null     int64
#  8   rank             24 non-null     int64
# dtypes: int64(8), object(1)
# memory usage: 1.8+ KB

# %%
premierleague.isnull().sum()
# Out:
# team               0
# goals_scored       0
# goals_conceded     0
# wins               0
# draws              0
# losses             0
# points             0
# goal_difference    0
# rank               0
# dtype: int64

# %%
premierleague.duplicated().sum()
# Out:
# 0

# %%
premierleague.describe()
# Out:
#        goals_scored  goals_conceded       wins      draws     losses  \
# count     24.000000       24.000000  24.000000  24.000000  24.000000
# mean      94.583333       94.583333  24.791667  13.750000  24.791667
# std       41.041778       29.057539  13.931444   5.358861  10.794440
# min       35.000000       50.000000   5.000000   5.000000   9.000000
# 25%       55.750000       67.750000  12.750000   9.000000  18.750000
# 50%       86.500000       99.000000  23.000000  14.500000  23.000000
# 75%      131.000000      114.750000  36.250000  18.000000  29.500000
# max      179.000000      167.000000  55.000000  26.000000  57.000000
#
#            points  goal_difference       rank
# count   24.000000        24.000000  24.000000
# mean    88.125000         0.000000  12.500000
# std     44.184704        47.120567   7.071068
# min     26.000000      -112.000000   1.000000
# 25%     46.750000       -27.250000   6.750000
# 50%     90.000000       -10.500000  12.500000
# ...

# %%
premierleague.describe().T
# Out:
#                  count       mean        std    min    25%   50%     75%  \
# goals_scored      24.0  94.583333  41.041778   35.0  55.75  86.5  131.00
# goals_conceded    24.0  94.583333  29.057539   50.0  67.75  99.0  114.75
# wins              24.0  24.791667  13.931444    5.0  12.75  23.0   36.25
# draws             24.0  13.750000   5.358861    5.0   9.00  14.5   18.00
# losses            24.0  24.791667  10.794440    9.0  18.75  23.0   29.50
# points            24.0  88.125000  44.184704   26.0  46.75  90.0  124.25
# goal_difference   24.0   0.000000  47.120567 -112.0 -27.25 -10.5   25.00
# rank              24.0  12.500000   7.071068    1.0   6.75  12.5   18.25
#
#                    max
# goals_scored     179.0
# goals_conceded   167.0
# wins              55.0
# draws             26.0
# losses            57.0
# points           177.0
# goal_difference  113.0
# rank              24.0

# %%
premierleague['team'].nunique()
# Out:
# 24

# %% [markdown]
# -There are total 24 teams participated in premierleague

# %%
premierleague['team'].unique()
# Out:
# array(['Manchester City', 'Liverpool', 'Arsenal', 'Manchester United',
#        'Chelsea', 'Tottenham Hotspur', 'Aston Villa', 'West Ham United',
#        'Everton', 'Newcastle United', 'Crystal Palace',
#        'Wolverhampton Wanderers', 'Brighton and Hove Albion', 'Fulham',
#        'Leicester City', 'Burnley', 'Leeds United', 'Bournemouth',
#        'Southampton', 'Brentford', 'Sheffield United',
#        'Nottingham Forest', 'Luton Town', 'West Bromwich Albion'],
#       dtype=object)

# %% [markdown]
# -These are the 24 team names

# %%
premierleague
# Out:
#                         team  goals_scored  goals_conceded  wins  draws  \
# 0            Manchester City           179              66    55     12
# 1                  Liverpool           154              83    44     19
# 2                    Arsenal           146              68    46     12
# 3          Manchester United           130             102    39     17
# 4                    Chelsea           135              99    37     19
# 5          Tottenham Hotspur           142             106    38     14
# 6                Aston Villa           131             107    36     15
# 7            West Ham United           122             121    33     18
# 8                    Everton            87              99    30     17
# 9           Newcastle United           131             124    30     15
# 10            Crystal Palace            98             124    25     18
# 11   Wolverhampton Wanderers            86             117    25     16
# ...

# %%
premiernum=premierleague.select_dtypes(include='number')

# %%
sns.heatmap(premiernum.corr(),annot=True);

# %% [markdown]
# -from this heatmap we can understand the positive and negative relation between each features

# %%
plt.figure(figsize=(10,5))
sns.lineplot(x='team',y='goals_scored',marker='o',data=premierleague)
sns.lineplot(x='team',y='goals_conceded',marker='d',data=premierleague)
plt.xlabel('Team name')
plt.ylabel('Goal scored and Conceded')
plt.title('Team goals scored and conceded')
plt.legend(['goal scored','goal conceded'])
plt.grid(True)
plt.xticks(rotation=90);

# %% [markdown]
# -From this we can understand Manchester City have scored more goals and less goals conceded

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='team',y='goal_difference',data=premierleague,color='yellow')
plt.grid(True)
plt.xticks(rotation=90);

# %% [markdown]
# -From this plot we can understand the goal difference between each team here ManchesterCity have a huge positive goal difference

# %%
top5=premierleague.head()

# %%
top5
# Out:
#                 team  goals_scored  goals_conceded  wins  draws  losses  \
# 0    Manchester City           179              66    55     12       9
# 1          Liverpool           154              83    44     19      13
# 2            Arsenal           146              68    46     12      18
# 3  Manchester United           130             102    39     17      20
# 4            Chelsea           135              99    37     19      20
#
#    points  goal_difference  rank
# 0     177              113     1
# 1     151               71     2
# 2     150               78     3
# 3     134               28     4
# 4     130               36     5

# %%
plt.pie(top5['wins'],labels=top5['team'],explode=(0.1,0,0,0,0),shadow=True,autopct='%1f%%',colors=['lightblue','red','white','lightgreen','yellow'])
plt.title('Top 5 teams and thier win rate in 2024');

# %% [markdown]
# -We can inderstand the team with maximum win rate here it is ManchesterCity

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='team',y='points',color='r',data=premierleague)
plt.xticks(rotation=90)
plt.grid(True);

# %% [markdown]
# -From this we can see the points that each team scored in the premierleague

# %%
sns.pairplot(premierleague)

# %% [markdown]
# ## Team with highest win rate and goals

# %%
a=premierleague.nlargest(10,'wins')[['goals_scored','team']]
a
# Out:
#    goals_scored               team
# 0           179    Manchester City
# 2           146            Arsenal
# 1           154          Liverpool
# 3           130  Manchester United
# 5           142  Tottenham Hotspur
# 4           135            Chelsea
# 6           131        Aston Villa
# 7           122    West Ham United
# 8            87            Everton
# 9           131   Newcastle United

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x=a['team'],y=a['goals_scored'],data=a)
plt.xticks(rotation=90);
